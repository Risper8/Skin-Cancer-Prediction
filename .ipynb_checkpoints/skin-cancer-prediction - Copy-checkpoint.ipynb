# %%
import os
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout,Input

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 64
CHANNELS = 3

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "C:/Users/user/OneDrive/Documents/SKIN CANCER/multiple-skin-disease-detection-and-classification/Skin Cancer Dataset",
    shuffle=True,   # to randomly shuffle the images
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 4107 files belonging to 9 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Acitinic Keratosis',
#  'Basal Cell Carcinoma',
#  'Dermatofibroma',
#  'Melanoma',
#  'Nevus',
#  'Pigmented Benign Keratosis',
#  'Seborrheic Keratosis',
#  'Squamous Cell Carcinoma',
#  'Vascular Lesion']

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (64, 256, 256, 3)
# [6 3 5 3 4 1 7 3 3 3 5 5 5 7 5 7 6 4 4 7 4 1 6 5 6 1 8 3 3 6 4 3 3 5 4 0 0
#  5 1 6 6 4 6 7 1 8 1 2 0 4 2 4 5 7 6 1 3 0 3 3 3 6 6 2]

# %%
plt.figure(figsize=(12,12))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4, i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
# spliting he dataset using a function
def get_datset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle= True, shuffle_size=10000):
    ds_size= len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    train_size= int(train_split* ds_size)
    val_size=int(val_split * ds_size)
    train_ds = dataset.take(train_size)
    val_ds = dataset.skip(train_size).take(val_size)
    test_ds = dataset.skip(train_size).skip(val_size)

    return train_ds, val_ds,test_ds

# %%
train_ds, val_ds,test_ds = get_datset_partitions_tf(dataset)

# %%
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (52, 6, 7)

# %%
#train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
#val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
# test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE))),
    tf.keras.layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
   layers.RandomFlip("horizontal" or "vertical"),
   layers.RandomRotation(0.2),
   layers.RandomZoom(0.2),
   #layers.RandomTranslation(height_factor=0.2, width_factor=0.2),  
#    layers.RandomContrast(factor=0.1),              # Adjusts contrast randomly by up to 10%
#    layers.RandomBrightness(factor=0.1) 
])

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(3):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
# from tensorflow.keras.applications import VGG16 
from tensorflow.keras.applications import EfficientNetB0
# Load pre-trained model 
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
base_model.trainable = False  

# Add custom layers for fine-tuning
inputs = Input(shape=(256,256, 3))
x=resize_and_rescale(inputs)
x = data_augmentation(inputs)
x = base_model.output
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)  
x = Dropout(0.5)(x)  
predictions = Dense(9, activation='softmax')(x)  

# Create the final fine-tuned model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
from keras import optimizers
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5, beta_1=0.9, beta_2=0.999),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import Callback,EarlyStopping
# # Define a custom callback to stop when validation accuracy reaches 0.90 and training accuracy reaches 0.90
# class StopAtValAccuracy(Callback):
#     def on_epoch_end(self, epoch, logs=None):
#         val_accuracy = logs.get('val_accuracy')
#         accuracy = logs.get('accuracy')
#         if val_accuracy is not None and val_accuracy >= 0.85 and accuracy is not None and accuracy >= 0.85:
#             print(f"\nReached {val_accuracy*100:.2f}% val_accuracy and {accuracy*100:.2f}% accuracy, stopping training!")
#             self.model.stop_training = True

# # Instantiate the custom callback
# stop_at_val_accuracy = StopAtValAccuracy()
#early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1,
                           #mode='auto', restore_best_weights=True)

# %%
history = model.fit(
    train_ds,
    epochs=20,
    batch_size = BATCH_SIZE,
    validation_data=val_ds,
    verbose=1
    #callbacks=[early_stop]

)
# Out:
# Epoch 1/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 350s 6s/step - accuracy: 0.3410 - loss: 2.1859 - val_accuracy: 0.6667 - val_loss: 1.0344
# Epoch 2/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 290s 6s/step - accuracy: 0.6675 - loss: 0.9777 - val_accuracy: 0.6875 - val_loss: 0.9215
# Epoch 3/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 384s 7s/step - accuracy: 0.7595 - loss: 0.7148 - val_accuracy: 0.7734 - val_loss: 0.7432
# Epoch 4/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 512s 9s/step - accuracy: 0.8325 - loss: 0.5277 - val_accuracy: 0.7708 - val_loss: 0.7240
# Epoch 5/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 283s 5s/step - accuracy: 0.8774 - loss: 0.4069 - val_accuracy: 0.7917 - val_loss: 0.6310
# Epoch 6/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 330s 6s/step - accuracy: 0.8975 - loss: 0.3219 - val_accuracy: 0.8464 - val_loss: 0.5492
# Epoch 7/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 344s 7s/step - accuracy: 0.9175 - loss: 0.2680 - val_accuracy: 0.8125 - val_loss: 0.5985
# Epoch 8/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 512s 10s/step - accuracy: 0.9241 - loss: 0.2441 - val_accuracy: 0.8568 - val_loss: 0.4970
# Epoch 9/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 395s 8s/step - accuracy: 0.9436 - loss: 0.1938 - val_accuracy: 0.8385 - val_loss: 0.4918
# Epoch 10/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 352s 7s/step - accuracy: 0.9464 - loss: 0.1759 - val_accuracy: 0.8464 - val_loss: 0.5398
# Epoch 11/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 478s 9s/step - accuracy: 0.9588 - loss: 0.1462 - val_accuracy: 0.8672 - val_loss: 0.5086
# Epoch 12/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 449s 8s/step - accuracy: 0.9666 - loss: 0.1234 - val_accuracy: 0.8490 - val_loss: 0.5136
# Epoch 13/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 420s 8s/step - accuracy: 0.9663 - loss: 0.1270 - val_accuracy: 0.8516 - val_loss: 0.5792
# Epoch 14/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 397s 8s/step - accuracy: 0.9626 - loss: 0.1184 - val_accuracy: 0.8750 - val_loss: 0.4609
# Epoch 15/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 591s 11s/step - accuracy: 0.9749 - loss: 0.0991 - val_accuracy: 0.8646 - val_loss: 0.5192
# Epoch 16/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 505s 9s/step - accuracy: 0.9710 - loss: 0.1079 - val_accuracy: 0.8411 - val_loss: 0.5126
# Epoch 17/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 474s 9s/step - accuracy: 0.9651 - loss: 0.1272 - val_accuracy: 0.8750 - val_loss: 0.4625
# Epoch 18/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 288s 6s/step - accuracy: 0.9795 - loss: 0.0830 - val_accuracy: 0.8724 - val_loss: 0.4753
# Epoch 19/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 322s 6s/step - accuracy: 0.9692 - loss: 0.1039 - val_accuracy: 0.8750 - val_loss: 0.4342
# Epoch 20/20
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 326s 6s/step - accuracy: 0.9823 - loss: 0.0791 - val_accuracy: 0.8568 - val_loss: 0.5789

# %% [markdown]
# ## evaluation

# %%
#model.evaluate(test_ds)

# %%
import numpy as np
y_pred = []
y_true = []

for image_batch, label_batch in test_ds:
    predictions = model.predict(image_batch)
    predicted_labels = np.argmax(predictions, axis=-1)
    y_pred.extend(predicted_labels)
    y_true.extend(label_batch.numpy())
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 24s 12s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %%
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# Print shapes to verify
print("Predicted labels shape:", y_pred.shape)
print("True labels shape:", y_true.shape)
# Out:
# Predicted labels shape: (395,)
# True labels shape: (395,)

# %%
from sklearn.metrics import classification_report, accuracy_score
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8455696202531645

# %%
# Print classification report
class_names = ["nevus", "melanoma", "squamous cell carcinoma", "basal cell carcinoma", "actinic keratosis", "vascular lesion", "dermatofibroma", "seborrheic keratosis", "pigmented benign keratosis"]
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                             precision    recall  f1-score   support
#
#                      nevus       0.87      0.75      0.81        53
#                   melanoma       0.88      0.79      0.83        56
#    squamous cell carcinoma       0.78      0.90      0.84        31
#       basal cell carcinoma       0.79      0.89      0.84        37
#          actinic keratosis       0.91      0.96      0.94        53
#            vascular lesion       0.95      0.95      0.95        40
#             dermatofibroma       0.77      0.69      0.73        49
#       seborrheic keratosis       0.79      0.86      0.83        44
# pigmented benign keratosis       0.85      0.88      0.86        32
#
#                   accuracy                           0.85       395
#                  macro avg       0.84      0.85      0.85       395
#               weighted avg       0.85      0.85      0.84       395

# %% [markdown]
# ## save the model

# %%
#model.save('skin_cancer_model.keras')
